# %% [markdown]
# # Data Process Pipeline

# %% [markdown]
# First, you should add hosts in your ~/.ssh/config file

# %%
import os
import paramiko
import time

HOSTS = ["h800-80", "h800-81", "h800-82", "h800-83", "h800-84", "h800-85", "h800-86", "h800-170", "h800-171"]

# load from ~/.ssh/config
ssh_config = paramiko.SSHConfig()
user_config_file = os.path.expanduser("~/.ssh/config")
if os.path.exists(user_config_file):
    with open(user_config_file) as f:
        ssh_config.parse(f)


def get_ssh_config(hostname):
    # get the configuration for the host
    user_config = ssh_config.lookup(hostname)
    cfg = {
        "hostname": user_config["hostname"],
        "username": user_config["user"],
        "port": int(user_config["port"]),
        "key_filename": user_config["identityfile"],
    }
    return cfg


def connect(hostname):
    cfg = get_ssh_config(hostname)
    # connect
    client = paramiko.SSHClient()
    client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    client.connect(**cfg)
    return client


def run_command(command, hostname, nohup=False, log_file=None, sleep=None):
    client = connect(hostname)
    print("HOST:", hostname)
    if sleep:
        command = f"sleep {sleep}; {command}"
    command = f"bash -ic '{command}'"
    if log_file:
        command = f"{command} >> {log_file} 2>&1"
    if nohup:
        command = f"nohup {command} &"
    print("COMMAND:", command)
    stdin, stdout, stderr = client.exec_command(command, get_pty=False)

    stdout_str = stdout.read().decode()
    stderr_str = stderr.read().decode()
    if stdout_str:
        print("==== STDOUT ====\n", stdout_str)
    if stderr_str:
        print("==== STDERR ====\n", stderr_str)

    client.close()


def run_command_all_hosts(command, hosts=HOSTS):
    for hostname in hosts:
        run_command(command, hostname)

# %% [markdown]
# Here are tools to examine machine's status.

# %%
def nvidia_smi(host):
    if host:
        run_command("nvidia-smi", host)
    else:
        run_command_all_hosts("nvidia-smi")


def nvitop(host=None):
    if host:
        run_command(f"/home/zhaowangbo/.local/bin/nvitop -1", host)
    else:
        run_command_all_hosts("/home/zhaowangbo/.local/bin/nvitop -1")


def ps(host=None, interest="python|sleep|torchrun|colossal"):
    if host:
        if interest is None:
            run_command("ps ux | cat", host)
        else:
            run_command(f'ps ux | cat | grep --color=never -E "{interest}"', host)
    else:
        if interest is None:
            run_command_all_hosts("ps ux | cat")
        else:
            run_command_all_hosts(f'ps ux | cat | grep --color=never -E "{interest}"')


def kill(pid, host):
    run_command(f"kill -KILL {pid}", host)

# %% [markdown]
# Here we define different tasks.

# %%
OPEN_SORA_HOME = "/home/zhaowangbo/zangwei/opensora/"


def convert_dataset_cmd(input_dir, output_file, datatype="video"):
    commands = []
    commands.append(f'echo "Converting {input_dir} to {output_file}"')
    output_dir = os.path.dirname(output_file)

    commands.append(f"mkdir -p {output_dir}")
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(f"python -m tools.datasets.convert {datatype} {input_dir} --output {output_file}")
    return " && ".join(commands), output_file


def get_video_info(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_info{ext}"
    output_format = ext[1:]

    commands.append(f'echo "Getting info of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(
        f"python -m tools.datasets.datautil {input_file} --output {output_file} --format {output_format} --info --fmin 1"
    )
    return " && ".join(commands), output_file

def get_video_info_torchvision(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_info{ext}"
    output_format = ext[1:]

    commands.append(f'echo "Getting info of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(
        f"python -m tools.datasets.datautil {input_file} --output {output_file} --format {output_format} --video-info --fmin 1"
    )
    return " && ".join(commands), output_file


def get_caption_llava7b_video(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_info{ext}"
    output_format = ext[1:]

    commands.append(f'echo "Getting info of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(
        f"torchrun --nproc_per_node 8 --standalone -m tools.caption.caption_llava {input_file} --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video"
    )
    commands.append(
        f"python -m tools.datasets.datautil {base}_part*{ext} --output {output_file} --format {output_format} --intersection {input_file} --clean-caption --refine-llm-caption --remove-empty-caption"
    )


def get_caption_load(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_caption{ext}"
    output_format = ext[1:]

    commands.append(f'echo "Getting caption of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(
        f"python -m tools.datasets.datautil {input_file} --output {output_file} --format {output_format} --load-caption json --remove-empty-caption --clean-caption"
    )
    return " && ".join(commands), output_file


def get_aesthetic_score(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_aes{ext}"
    output_format = ext[1:]

    commands.append(f'echo "Getting aesthetic score of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(f"torchrun --standalone --nproc_per_node 8 -m tools.scoring.aesthetic.inference {input_file}")
    commands.append(
        f"python -m tools.datasets.datautil {base}_part*{ext} --output {output_file} --format {output_format} --sort aes"
    )
    return " && ".join(commands), output_file


def get_flow_score(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_flow{ext}"

    commands.append(f'echo "Getting flow score of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(f"torchrun --standalone --nproc_per_node 8 -m tools.scoring.optical_flow.inference {input_file}")
    return " && ".join(commands), output_file


def get_match_score(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_match{ext}"

    commands.append(f'echo "Getting match score of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(f"torchrun --standalone --nproc_per_node 8 -m tools.scoring.matching.inference {input_file}")
    return " && ".join(commands), output_file


def get_cmotion_score(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_cmotion{ext}"

    commands.append(f'echo "Getting cmotion score of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(f"python -m tools.caption.camera_motion_detect {input_file}")
    return " && ".join(commands), output_file


def get_commands(job_list):
    commands = []
    output_file = None
    for job in job_list:
        cmd = job.pop("cmd")
        if output_file is None:
            command, output_file = cmd(**job)
            commands.append(command)
        else:
            job["input_file"] = output_file
            command, output_file = cmd(**job)
            commands.append(command)
    commands.append(f'echo "All Done!"')
    return " && ".join(commands), output_file

# %% [markdown]
# The following is the pipeline for panda.

# %%
host = "h800-81"
split = 24
input_dir = f"/mnt/disk0/data-panda/{split}"
log_file = os.path.join(OPEN_SORA_HOME, f"logs/data-panda-{split}-split.log")
output_file = f"/mnt/hdd/data/panda70m_by/raw/meta/split-{split}/meta.csv"
cmd, output_file = get_commands(
    [
        {
            "cmd": convert_dataset_cmd,
            "input_dir": input_dir,
            "output_file": output_file,
        },
        {
            "cmd": get_caption_load,
        },
        {
            "cmd": get_video_info_torchvision,
        },
        # {
        #     "cmd": get_aesthetic_score,
        # },
        # {
        #     "cmd": get_flow_score,
        # },
        # {
        #     "cmd": get_match_score,
        # },
        # {
        #     "cmd": get_cmotion_score,
        # },
    ]
)
print(cmd)
print(output_file)
# Out:
# echo "Converting /mnt/disk0/data-panda/24 to /mnt/hdd/data/panda70m_by/raw/meta/split-24/meta.csv" && mkdir -p /mnt/hdd/data/panda70m_by/raw/meta/split-24 && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.convert video /mnt/disk0/data-panda/24 --output /mnt/hdd/data/panda70m_by/raw/meta/split-24/meta.csv && echo "Getting caption of /mnt/hdd/data/panda70m_by/raw/meta/split-24/meta.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-24/meta_caption.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-24/meta.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-24/meta_caption.csv --format csv --load-caption json --remove-empty-caption --clean-caption && echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-24/meta_caption.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-24/meta_caption_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-24/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-24/meta_caption_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# /mnt/hdd/data/panda70m_by/raw/meta/split-24/meta_caption_info.csv

# %%
host = "h800-82"
split = 7
log_file = os.path.join(OPEN_SORA_HOME, f"logs/data-panda-{split}-split.log")
cmd, output_file = get_commands(
    [
        {
            "cmd": get_video_info_torchvision,
            "input_file": f"/mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean.csv",
        },
    ]
)
print(cmd)
print(output_file)
# Out:
# echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean_info.csv

# %%
sleep = "9h"
run_command(cmd, host, log_file=log_file, nohup=True, sleep=sleep)
ps(host)
# Out:
# HOST: h800-82
# COMMAND: nohup bash -ic 'sleep 9h; echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean_info.csv --format csv --video-info --fmin 1 && echo "All Done!"' >> /home/zhaowangbo/zangwei/opensora/logs/data-panda-7-split.log 2>&1 &
# HOST: h800-82
# COMMAND: bash -ic 'ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"'
# ==== STDOUT ====
#  zhaowan+  174693  0.0  0.0   8496  5148 ?        S    01:59   0:00 bash -ic sleep 3h; echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-3/meta_remove_corrupted_loadjson_noempty_clean_info.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-3/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-3/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-3/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# zhaowan+  176000  0.0  0.0   5492   588 ?        S    01:59   0:00 sleep 3h
# zhaowan+  203444  0.0  0.0   8496  5164 ?        S    02:00   0:00 bash -ic sleep 6h; echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# zhaowan+  244363  0.0  0.0   5492   524 ?        S    02:00   0:00 sleep 6h
# zhaowan+  262359  0.1  0.0   8496  5228 ?        S    02:00   0:00 bash -ic sleep 9h; echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# zhaowan+  319583  0.0  0.0   5492   592 ?        S    02:01   0:00 sleep 9h
# zhaowan+  322729 10.0  0.0   8488  5056 ?        Ss   02:01   0:00 bash -ic ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"
# zhaowan+  323854  0.0  0.0   6412   660 ?        S    02:01   0:00 grep --color=auto --color=never -E python|sleep|torchrun|colossal
# zhaowan+ 2287475  0.0  0.0   8496  5140 ?        S    01:28   0:00 bash -ic echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# zhaowan+ 2287568  2.0  0.0 17858200 492768 ?     Sl   01:28   0:41 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2287884  3.5  0.0 24781812 445572 ?     Sl   01:28   1:10 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2287889 81.7  0.2 24651188 4575400 ?    Rl   01:28  26:49 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2287891 81.2  0.4 29534760 9090616 ?    Rl   01:28  26:39 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 
python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2288066 81.7  0.2 25643340 5443816 ?    Il   01:28  26:48 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2288068 80.6  0.3 27484244 7161984 ?    Rl   01:28  26:27 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2288070 85.0  0.1 23549224 3472712 ?    Rl   01:28  27:54 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2288072 81.4  0.4 29936800 9860108 ?    Rl   01:28  26:43 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2288074 81.8  0.2 25994076 5672512 ?    Rl   01:28  26:51 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2288076 81.7  0.3 27228232 7152348 ?    Rl   01:28  26:48 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2288078 77.4  0.2 25083652 4761348 ?    Rl   01:28  25:23 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2288080 81.0  0.4 31252608 8537844 ?    Rl   01:28  26:35 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
#
# ==== STDERR ====
#  bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell

# %%
kill(1922317, host)
ps(host)
# Out:
# HOST: h800-84
# COMMAND: bash -ic 'kill -KILL 1922317'
# ==== STDERR ====
#  bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
#
# HOST: h800-84
# COMMAND: bash -ic 'ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"'
# ==== STDOUT ====
#  zhaowan+ 1262361  0.0  0.0  14180  5296 ?        S    01:54   0:00 bash -ic sleep 3h; echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-2/meta_remove_corrupted_loadjson_noempty_clean.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-2/meta_remove_corrupted_loadjson_noempty_clean_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-2/meta_remove_corrupted_loadjson_noempty_clean.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-2/meta_remove_corrupted_loadjson_noempty_clean_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# zhaowan+ 1288071  0.0  0.0  11168   524 ?        S    01:54   0:00 sleep 3h
# zhaowan+ 1354819  0.0  0.0  14180  5232 ?        S    01:54   0:00 bash -ic sleep 6h; echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-4/meta_loadjson_noempty_clean_info.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-4/meta_loadjson_noempty_clean_info_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-4/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-4/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# zhaowan+ 1359377  0.0  0.0  11168   592 ?        S    01:54   0:00 sleep 6h
# zhaowan+ 1522643  0.0  0.0  14180  5348 ?        S    01:55   0:00 bash -ic sleep 9h; echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-6/meta_loadjson_noempty_clean_info.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-6/meta_loadjson_noempty_clean_info_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-6/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-6/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# zhaowan+ 1526854  0.0  0.0  11168   592 ?        S    01:55   0:00 sleep 9h
# zhaowan+ 2067689  0.0  0.0  14180  5184 ?        S    01:40   0:00 bash -ic sleep 1m; echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# zhaowan+ 2068244  4.2  0.0 18185172 812836 ?     Sl   01:41   0:43 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2068405  6.1  0.0 25108784 763768 ?     Sl   01:41   1:01 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2068410 66.5  0.1 40081464 4002872 ?    Rl   01:41  11:02 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2068412 84.9  0.1 53370912 2699136 ?    Rl   01:41  14:06 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2068414 71.3  0.1 45830048 3300632 ?    Rl   01:41  11:50 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2068416 64.5  0.1 36159696 2181696 ?    Rl   01:41  10:42 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2068418 68.6  0.1 40646848 4147996 ?    Rl   01:41  11:23 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2068420 70.2  0.1 41765964 3046216 ?    Il   01:41  11:39 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2068422 88.3  0.2 64657824 4617116 ?    Rl   01:41  14:40 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 
python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2068596 68.7  0.1 51889088 3185148 ?    Il   01:41  11:24 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2068598 64.8  0.1 34944796 2290740 ?    Il   01:41  10:45 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2068600 63.9  0.4 46367296 9048748 ?    Rl   01:41  10:36 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-1/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2106235  0.0  0.0  11168   524 ?        S    01:57   0:00 sleep 3h
# zhaowan+ 2321296 11.0  0.0  14176  5432 ?        Ss   01:58   0:00 bash -ic ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"
# zhaowan+ 2326357  0.0  0.0  12124  2668 ?        S    01:58   0:00 grep --color=auto --color=never -E python|sleep|torchrun|colossal
#
# ==== STDERR ====
#  bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell

# %% [markdown]
# Using following commands to monitor the status of the jobs.

# %%
ps(host)
# Out:
# HOST: h800-80
# COMMAND: bash -ic 'ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"'
# ==== STDOUT ====
#  zhaowan+  599938  0.0  0.0   5492   592 ?        S    01:44   0:00 sleep 3h
# zhaowan+  820507  9.0  0.0   8488  5256 ?        Ss   01:45   0:00 bash -ic ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"
# zhaowan+  823896  0.0  0.0   6412   724 ?        S    01:45   0:00 grep --color=auto --color=never -E python|sleep|torchrun|colossal
# zhaowan+ 2900571  0.0  0.0   8496  5244 ?        S    01:31   0:00 bash -ic echo "Converting /mnt/disk0/data-panda/17 to /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta.csv" && mkdir -p /mnt/hdd/data/panda70m_by/raw/meta/split-17 && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.convert video /mnt/disk0/data-panda/17 --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta.csv && echo "Getting caption of /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --format csv --load-caption json --remove-empty-caption --clean-caption && echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# zhaowan+ 2912258  5.1  0.0 17862408 464236 ?     Sl   01:33   0:36 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912747  7.5  0.0 24784996 447148 ?     Sl   01:33   0:52 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912752 99.6  0.3 27611876 7062424 ?    Rl   01:33  11:38 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912754 99.6  0.3 28230888 6993972 ?    Rl   01:33  11:38 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912756 99.6  0.4 29655612 9474388 ?    Rl   01:33  11:38 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912758 99.6  0.2 25897644 5593840 ?    Rl   01:33  11:38 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912760 99.6  0.3 27507452 7204044 ?    Rl   01:33  11:38 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912762 99.6  0.2 25852868 5426576 ?    Rl   01:33  11:38 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912764 99.6  0.2 26248672 5576544 ?    Rl   01:33  11:38 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912766 99.6  0.5 31998688 11054616 ?   Rl   01:33  11:38 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912768 99.4  0.1 23769996 3466092 ?    Rl   01:33  11:37 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912770 99.6  0.2 25804460 5623292 ?    Rl   01:33  11:38 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912772 99.6  0.2 24610896 4307488 ?    Rl   01:33  11:38 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912774 99.6  0.3 27691860 7510764 ?    Rl   01:33  11:38 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912776  104  0.4 115059480 9288680 ?   Rl   01:33  12:12 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 2912778 99.5  0.2 25696184 5146896 ?    Rl   01:33  11:38 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-17/meta_caption_info.csv --format csv --video-info --fmin 1
# zhaowan+ 
ash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell

# %%
ps()
# Out:
# HOST: h800-80
# COMMAND: bash -ic 'ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"'
# ==== STDOUT ====
#  zhaowan+ 2508488  0.9  0.0 62146500 335516 pts/62 Sl  00:23   0:23 /home/zhaowangbo/.conda/envs/opensora/bin/python /home/zhaowangbo/.conda/envs/opensora/bin/colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2509916  0.4  0.0 62277572 223088 pts/62 Sl  00:23   0:11 /home/zhaowangbo/.conda/envs/opensora/bin/python /home/zhaowangbo/.conda/envs/opensora/bin/colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2509917  0.4  0.0 62343108 225364 pts/62 Sl  00:23   0:10 /home/zhaowangbo/.conda/envs/opensora/bin/python /home/zhaowangbo/.conda/envs/opensora/bin/colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2509918  0.4  0.0 62343108 225360 pts/62 Sl  00:23   0:11 /home/zhaowangbo/.conda/envs/opensora/bin/python /home/zhaowangbo/.conda/envs/opensora/bin/colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2509919  0.4  0.0 62343108 225360 pts/62 Sl  00:23   0:10 /home/zhaowangbo/.conda/envs/opensora/bin/python /home/zhaowangbo/.conda/envs/opensora/bin/colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2509920  0.4  0.0 62343108 225348 pts/62 Sl  00:23   0:10 /home/zhaowangbo/.conda/envs/opensora/bin/python /home/zhaowangbo/.conda/envs/opensora/bin/colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2509921  0.4  0.0 62343108 225376 pts/62 Sl  00:23   0:10 /home/zhaowangbo/.conda/envs/opensora/bin/python /home/zhaowangbo/.conda/envs/opensora/bin/colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2509922  0.4  0.0 62343108 225376 pts/62 Sl  00:23   0:10 /home/zhaowangbo/.conda/envs/opensora/bin/python /home/zhaowangbo/.conda/envs/opensora/bin/colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2509923  0.4  0.0 62343108 225376 pts/62 Sl  00:23   0:10 /home/zhaowangbo/.conda/envs/opensora/bin/python /home/zhaowangbo/.conda/envs/opensora/bin/colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2509924  0.7  0.0 20806104 300932 pts/62 Sl  00:23   0:18 /home/zhaowangbo/.conda/envs/opensora/bin/python /home/zhaowangbo/.conda/envs/opensora/bin/torchrun --nproc_per_node=8 --nnodes=8 --node_rank=0 --master_addr=10.20.1.80 --master_port=29500 scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2511006  134  0.5 124903600 11474180 ?  Ssl  00:23  52:03 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2511007  134  0.6 124280820 13743976 ?  Ssl  00:23  51:54 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2511008  135  0.6 105990928 12947264 ?  Ssl  00:23  52:10 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2511009  135  0.6 116960388 13623620 ?  Ssl  00:23  52:15 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2511010 92.3  0.6 118110784 13164180 ?  Ssl  00:23  35:37 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2511011 92.5  0.5 95954420 11648152 ?   Ssl  00:23  35:42 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2511012 92.2  0.5 113079028 12292900 ?  Ssl  00:23  35:36 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 2511013 92.3  0.6 119600720 13289524 ?  Ssl  00:23  35:37 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+ 
/home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  123392  3.4  0.3 72158780 8116516 ?    Sl   00:37   0:55 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  123455  2.1  0.3 72409968 8072876 ?    Sl   00:37   0:33 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  123546  2.8  0.3 70490828 6522300 ?    Sl   00:37   0:44 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  123563  1.7  0.3 72276652 7863008 ?    Sl   00:37   0:28 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  123583  2.1  0.3 70431412 6462832 ?    Sl   00:37   0:34 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  123757  3.0  0.3 71458756 7293788 ?    Sl   00:37   0:47 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  123896  1.9  0.3 70803708 6641372 ?    Sl   00:37   0:30 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  123897  1.6  0.3 70586316 6740684 ?    Sl   00:37   0:26 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  124148  2.2  0.3 71501648 7459620 ?    Sl   00:37   0:35 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  124149  3.0  0.3 72552488 8387624 ?    Sl   00:37   0:48 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  124207  1.8  0.3 70308448 6462020 ?    Sl   00:37   0:28 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  124216  2.3  0.3 71672824 7303504 ?    Sl   00:37   0:37 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  124590  2.7  0.3 72167568 8125976 ?    Sl   00:37   0:43 /home/zhaowangbo/.conda/envs/opensora/bin/python -u scripts/train.py configs/opensora-v1-1/train/video.py --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --wandb True --load outputs/764-STDiT2-XL-2/epoch1-global_step6000
# zhaowan+  141814  5.0  0.0   8496  5120 ?        Ss   01:03   0:00 bash -ic ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"
# zhaowan+  141954  0.0  0.0   6444   724 ?        S    01:03   0:00 grep --color=auto --color=never -E python|sleep|torchrun|colossal
#
# ==== STDERR ====
#  bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell

# %%
nvitop(host)

# %%
kill(, host)

# %% [markdown]
# # Training

# %%
def colossal_run(data_path, load_path=None):
    commands = []
    commands.append(f"cd {OPEN_SORA_HOME}")
    command = f"colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --wandb True --data-path {data_path}"
    if load_path:
        command = f"{command} --load-path {load_path}"
    commands.append(command)
    cmd = " && ".join(commands)
    return cmd


def kill_all():
    commands = []
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append('cat hostfile  | xargs -I "{}" ssh "{}" pkill -9 python')
    cmd = " && ".join(commands)
    return cmd

# %%
host = "h800-80"
log_file = os.path.join(OPEN_SORA_HOME, "logs/train_02.log")
data_path = "/home/zhaowangbo/data/csv/video_image_test_2.csv"
ckpt_path = "outputs/764-STDiT2-XL-2/epoch1-global_step6000"
cmd = colossal_run(data_path, ckpt_path)
print(cmd)
# Out:
# cd /home/zhaowangbo/zangwei/opensora/ && colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --wandb True --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --load-path outputs/764-STDiT2-XL-2/epoch1-global_step6000

# %%
run_command(cmd, host, log_file=log_file, nohup=True)

# %%
cmd = kill_all()
run_command(cmd, host)
# Out:
# HOST: h800-80
# COMMAND: bash -ic 'cd /home/zhaowangbo/zangwei/opensora/ && cat hostfile  | xargs -I "{}" ssh "{}" pkill -9 python'
# ==== STDERR ====
#  bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# pkill: killing pid 382879 failed: Operation not permitted
