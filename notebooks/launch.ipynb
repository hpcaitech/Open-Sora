# %% [markdown]
# # Data Process Pipeline

# %% [markdown]
# ### Data Process Commands

# %%
OPEN_SORA_HOME = "/home/zhaowangbo/zangwei/opensora/"


def convert_dataset_cmd(input_dir, output_file, datatype="video"):
    commands = []
    commands.append(f'echo "Converting {input_dir} to {output_file}"')
    output_dir = os.path.dirname(output_file)

    commands.append(f"mkdir -p {output_dir}")
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(f"python -m tools.datasets.convert {datatype} {input_dir} --output {output_file}")
    return " && ".join(commands), output_file


def get_video_info(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_info{ext}"
    output_format = ext[1:]

    commands.append(f'echo "Getting info of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(
        f"python -m tools.datasets.datautil {input_file} --output {output_file} --format {output_format} --info --fmin 1"
    )
    return " && ".join(commands), output_file

def get_video_info_torchvision(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_info{ext}"
    output_format = ext[1:]

    commands.append(f'echo "Getting info of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(
        f"python -m tools.datasets.datautil {input_file} --output {output_file} --format {output_format} --video-info --fmin 1"
    )
    return " && ".join(commands), output_file


def get_caption_llava7b_video(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_caption{ext}"
    output_format = ext[1:]

    commands.append(f'echo "Getting info of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(f"conda activate llava2")
    commands.append(
        f"torchrun --nproc_per_node 8 --standalone -m tools.caption.caption_llava {input_file} --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video"
    )
    commands.append(f"conda activate opensora")
    commands.append(
        f"python -m tools.datasets.datautil {base}_caption_part*{ext} --output {output_file} --format {output_format} --intersection {input_file} --clean-caption --refine-llm-caption --remove-empty-caption"
    )
    return " && ".join(commands), output_file


def get_caption_load(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_caption{ext}"
    output_format = ext[1:]

    commands.append(f'echo "Getting caption of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(
        f"python -m tools.datasets.datautil {input_file} --output {output_file} --format {output_format} --load-caption json --remove-empty-caption --clean-caption"
    )
    return " && ".join(commands), output_file


def get_aesthetic_score(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_aes{ext}"
    output_format = ext[1:]

    commands.append(f'echo "Getting aesthetic score of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(f"torchrun --standalone --nproc_per_node 8 -m tools.scoring.aesthetic.inference {input_file}")
    commands.append(
        f"python -m tools.datasets.datautil {base}_aes_part*{ext} --output {output_file} --format {output_format} --sort aes"
    )
    return " && ".join(commands), output_file


def get_flow_score(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_flow{ext}"

    commands.append(f'echo "Getting flow score of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(f"torchrun --standalone --nproc_per_node 8 -m tools.scoring.optical_flow.inference {input_file}")
    return " && ".join(commands), output_file


def get_match_score(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_match{ext}"

    commands.append(f'echo "Getting match score of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(f"torchrun --standalone --nproc_per_node 8 -m tools.scoring.matching.inference {input_file}")
    return " && ".join(commands), output_file


def get_cmotion_score(input_file):
    commands = []
    base, ext = os.path.splitext(input_file)
    output_file = f"{base}_cmotion{ext}"

    commands.append(f'echo "Getting cmotion score of {input_file} to {output_file}"')
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append(f"python -m tools.caption.camera_motion_detect {input_file}")
    return " && ".join(commands), output_file


def get_commands(job_list):
    commands = []
    output_file = None
    for job in job_list:
        cmd = job.pop("cmd")
        if output_file is None:
            command, output_file = cmd(**job)
            commands.append(command)
        else:
            job["input_file"] = output_file
            command, output_file = cmd(**job)
            commands.append(command)
    commands.append(f'echo "All Done!"')
    return " && ".join(commands), output_file

# %% [markdown]
# ### Remote Launch via Paramiko
#
# First, you should add hosts in your ~/.ssh/config file

# %%
import os
import paramiko
import time

HOSTS = ["h800-80", "h800-81", "h800-82", "h800-83", "h800-84", "h800-85", "h800-86", "h800-170", "h800-171"]

# load from ~/.ssh/config
ssh_config = paramiko.SSHConfig()
user_config_file = os.path.expanduser("~/.ssh/config")
if os.path.exists(user_config_file):
    with open(user_config_file) as f:
        ssh_config.parse(f)


def get_ssh_config(hostname):
    # get the configuration for the host
    user_config = ssh_config.lookup(hostname)
    cfg = {
        "hostname": user_config["hostname"],
        "username": user_config["user"],
        "port": int(user_config["port"]),
        "key_filename": user_config["identityfile"],
    }
    return cfg


def connect(hostname):
    cfg = get_ssh_config(hostname)
    # connect
    client = paramiko.SSHClient()
    client.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    client.connect(**cfg)
    return client


def run_command(command, hostname, nohup=False, log_file=None, sleep=None):
    client = connect(hostname)
    print("HOST:", hostname)
    if sleep:
        command = f"sleep {sleep}; {command}"
    command = f"bash -ic '{command}'"
    if log_file:
        command = f"{command} >> {log_file} 2>&1"
    if nohup:
        command = f"nohup {command} &"
    print("COMMAND:", command)
    stdin, stdout, stderr = client.exec_command(command, get_pty=False)

    stdout_str = stdout.read().decode()
    stderr_str = stderr.read().decode()
    if stdout_str:
        print("==== STDOUT ====\n", stdout_str)
    if stderr_str:
        print("==== STDERR ====\n", stderr_str)

    client.close()


def run_command_all_hosts(command, hosts=HOSTS):
    for hostname in hosts:
        run_command(command, hostname)

# %% [markdown]
# Here are tools to examine machine's status.

# %%
def nvidia_smi(host):
    if host:
        run_command("nvidia-smi", host)
    else:
        run_command_all_hosts("nvidia-smi")


def nvitop(host=None):
    if host:
        run_command(f"/home/zhaowangbo/.local/bin/nvitop -1", host)
    else:
        run_command_all_hosts("/home/zhaowangbo/.local/bin/nvitop -1")


def ps(host=None, interest="python|sleep|torchrun|colossal"):
    if host:
        if interest is None:
            run_command("ps ux | cat", host)
        else:
            run_command(f'ps ux | cat | grep --color=never -E "{interest}"', host)
    else:
        if interest is None:
            run_command_all_hosts("ps ux | cat")
        else:
            run_command_all_hosts(f'ps ux | cat | grep --color=never -E "{interest}"')


def kill(pid, host):
    run_command(f"kill -KILL {pid}", host)


def pkill(interest, host):
    run_command(f'pkill -9 -f "{interest}"', host)

# %% [markdown]
# ### Examples
#
# The following is the pipeline for panda.

# %%
# panda
host = "h800-83"
split = 16
input_dir = f"/mnt/disk1/data-panda/{split}"
log_file = os.path.join(OPEN_SORA_HOME, f"logs/data-panda-{split}-split.log")
output_file = f"/mnt/hdd/data/panda70m_by/raw/meta/split-{split}/meta.csv"
cmd, output_file = get_commands(
    [
        # {
        #     "cmd": convert_dataset_cmd,
        #     "input_dir": input_dir,
        #     "output_file": output_file,
        # },
        # {
        #     "cmd": get_caption_load,
        # },
        # {
        #     "cmd": get_video_info_torchvision,
        # },
        # {
        #     "cmd": get_aesthetic_score,
        # },
        # {
        #     "cmd": get_flow_score,
        # },
        # {
        #     "cmd": get_match_score,
        # },
        # {
        #     "cmd": get_cmotion_score,
        # },
    ]
)
print(cmd)
print(output_file)
# Out:
# echo "Getting aesthetic score of /mnt/hdd/data/panda70m_by/raw/meta/split-16/meta_info_caption_info.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-16/meta_info_caption_info_aes.csv" && cd /home/zhaowangbo/zangwei/opensora/ && torchrun --standalone --nproc_per_node 8 -m tools.scoring.aesthetic.inference /mnt/hdd/data/panda70m_by/raw/meta/split-16/meta_info_caption_info.csv && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-16/meta_info_caption_info_part*.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-16/meta_info_caption_info_aes.csv --format csv --sort aes && echo "All Done!"
# /mnt/hdd/data/panda70m_by/raw/meta/split-16/meta_info_caption_info_aes.csv

# %%
# panda
host = "h800-82"
split = 7
log_file = os.path.join(OPEN_SORA_HOME, f"logs/data-panda-{split}-split.log")
cmd, output_file = get_commands(
    [
        {
            "cmd": get_video_info_torchvision,
            "input_file": f"/mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean.csv",
        },
    ]
)
print(cmd)
print(output_file)
# Out:
# echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# /mnt/hdd/data/panda70m_by/raw/meta/split-7/meta_loadjson_noempty_clean_info.csv

# %%
# v2text
host = "h800-86"
log_file = os.path.join(OPEN_SORA_HOME, f"logs/data-v2text-18.log")
input_file = "/home/zhaowangbo/data/v2text/raw/meta/split-18/meta_remove_corrupted.csv"
cmd, output_file = get_commands(
    [
        {
            "cmd": get_caption_llava7b_video,
            "input_file": input_file,
        },
    ]
)
print(cmd)
print(output_file)
# Out:
# echo "Getting info of /home/zhaowangbo/data/v2text/raw/meta/split-18/meta_remove_corrupted.csv to /home/zhaowangbo/data/v2text/raw/meta/split-18/meta_remove_corrupted_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && conda activate llava2 && torchrun --nproc_per_node 8 --standalone -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-18/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video && conda activate opensora && python -m tools.datasets.datautil /home/zhaowangbo/data/v2text/raw/meta/split-18/meta_remove_corrupted_caption_part*.csv --output /home/zhaowangbo/data/v2text/raw/meta/split-18/meta_remove_corrupted_info.csv --format csv --intersection /home/zhaowangbo/data/v2text/raw/meta/split-18/meta_remove_corrupted.csv --clean-caption --refine-llm-caption --remove-empty-caption && echo "All Done!"
# /home/zhaowangbo/data/v2text/raw/meta/split-18/meta_remove_corrupted_info.csv

# %% [markdown]
# Remote launch via paramiko.

# %%
sleep = None
run_command(cmd, host, log_file=log_file, nohup=True, sleep=sleep)
ps(host)
# Out:
# HOST: h800-80
# COMMAND: nohup bash -ic 'echo "Getting info of /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv to /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && conda activate llava2 && torchrun --nproc_per_node 8 --standalone -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video && conda activate opensora && python -m tools.datasets.datautil /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted_part*.csv --output /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted_info.csv --format csv --intersection /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --clean-caption --refine-llm-caption --remove-empty-caption && echo "All Done!"' >> /home/zhaowangbo/zangwei/opensora/logs/data-v2text-12.log 2>&1 &
# HOST: h800-80
# COMMAND: bash -ic 'ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"'
# ==== STDOUT ====
#  zhaowan+ 3482147  2.0  0.0   8496  5244 ?        S    13:24   0:00 bash -ic echo "Getting info of /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv to /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && conda activate llava2 && torchrun --nproc_per_node 8 --standalone -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video && conda activate opensora && python -m tools.datasets.datautil /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted_part*.csv --output /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted_info.csv --format csv --intersection /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --clean-caption --refine-llm-caption --remove-empty-caption && echo "All Done!"
ash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell

# %% [markdown]
# Using following commands to monitor the status of the jobs.

# %%
ps()
# Out:
# HOST: h800-80
# COMMAND: bash -ic 'ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"'
# ==== STDOUT ====
#  zhaowan+  220111  0.0  0.0   8488  5284 ?        Ss   14:17   0:00 bash -ic ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"
# zhaowan+  220578  0.0  0.0   6412   660 ?        S    14:17   0:00 grep --color=auto --color=never -E python|sleep|torchrun|colossal
# zhaowan+ 3495468  0.4  0.0 5777192 296060 pts/62 Sl+  13:26   0:13 /home/zhaowangbo/.conda/envs/llava2/bin/python /home/zhaowangbo/.conda/envs/llava2/bin/torchrun --nproc_per_node 8 --standalone -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3495632 98.2  0.2 115793484 6332416 ?   Rsl  13:26  49:55 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3495633 98.2  0.2 104071296 6282856 ?   Rsl  13:26  49:54 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3495634 98.2  0.3 111673472 6396044 ?   Rsl  13:26  49:54 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3495635 98.1  0.2 113877120 6314360 ?   Rsl  13:26  49:51 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3495636 98.0  0.3 116940928 6346284 ?   Rsl  13:26  49:49 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3495637 97.5  0.2 104030340 6336212 ?   Rsl  13:26  49:33 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3495638 97.9  0.3 120660096 6341044 ?   Rsl  13:26  49:46 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3495639 97.5  0.2 108781700 6337864 ?   Rsl  13:26  49:32 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508328 16.3  0.1 87706016 3461984 ?    Sl   13:28   7:53 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508329 17.0  0.1 87714780 3462352 ?    Sl   13:28   8:15 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508330 16.3  0.1 87731160 3475856 ?    Sl   13:28   7:54 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508331 15.9  0.1 87714780 3461472 ?    Sl   13:28   7:43 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508332 16.3  0.1 87722968 3485600 ?    Sl   13:28   7:54 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508333 16.5  0.1 87714776 3465328 ?    Sl   13:28   8:02 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508334 17.4  0.1 87731160 3482500 ?    Sl   13:28   8:26 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508335 16.3  0.1 87722968 3542548 ?    Sl   13:28   7:53 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508849 17.3  0.1 87714792 3472516 ?    Sl   13:28   8:24 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508917 16.9  0.1 87706028 3462224 ?    Sl   13:28   8:11 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508924 16.5  0.1 87731172 3476996 ?    Sl   13:28   8:01 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508981 17.8  0.1 87731172 3482652 ?    Sl   13:28   8:37 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3508986 16.3  0.1 87722980 3478544 ?    Sl   13:28   7:56 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509013 15.7  0.1 87813144 3467560 ?    Sl   13:28   7:38 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509232 15.9  0.1 87821332 3537344 ?    Sl   13:28   7:42 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509295 16.7  0.1 87714788 3462608 ?    Sl   13:28   8:05 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509358 15.2  0.1 87714804 3473160 ?    Sl   13:28   7:23 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509359 16.3  0.1 87706040 3472892 ?    Sl   13:28   7:56 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509455 15.8  0.1 87722992 3481716 ?    Sl   13:28   7:41 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509547 16.1  0.1 87706052 3462396 ?    Sl   13:28   7:47 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509610 16.4  0.1 87714800 3463884 ?    Sl   13:28   7:57 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509611 17.4  0.1 87731184 3489336 ?    Sl   13:28   8:26 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509736 16.0  0.1 87731184 3488892 ?    Sl   13:28   7:47 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509737 16.0  0.1 87723004 3477388 ?    Sl   13:28   7:45 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509738 17.6  0.1 87714804 3477800 ?    Sl   13:28   8:33 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509739 16.1  0.1 87722992 3537092 ?    Sl   13:28   7:50 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3509988 16.4  0.1 87706064 3467436 ?    Sl   13:28   7:56 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510054 17.1  0.1 87714812 3466536 ?    Sl   13:28   8:18 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510123 16.5  0.1 87731196 3476392 ?    Rl   13:28   8:01 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510193 17.2  0.1 87714816 3473148 ?    Sl   13:28   8:21 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510275 16.4  0.1 87723016 3490072 ?    Sl   13:28   7:57 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510276 15.8  0.1 87731196 3480164 ?    Sl   13:28   7:41 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510408 16.6  0.1 87706076 3462976 ?    Sl   13:28   8:03 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510423 15.8  0.1 87723004 3531000 ?    Sl   13:28   7:40 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510553 17.1  0.1 87714824 3461952 ?    Il   13:28   8:19 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510554 17.0  0.1 87714828 3470216 ?    Sl   13:28   8:14 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510616 17.2  0.1 87731208 3478612 ?    Sl   13:28   8:20 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510742 15.9  0.1 87723028 3487528 ?    Sl   13:28   7:42 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510743 16.1  0.1 87731208 3479732 ?    Sl   13:28   7:47 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510820 16.2  0.1 87706088 3467460 ?    Rl   13:28   7:52 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510931 16.1  0.1 87714816 3464840 ?    Sl   13:28   7:50 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3510932 15.5  0.1 87723016 3547664 ?    Sl   13:28   7:31 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511057 16.5  0.1 87714840 3459668 ?    Sl   13:28   7:59 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511074 16.5  0.1 87723040 3478992 ?    Sl   13:28   8:00 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511100 16.3  0.1 87714836 3465392 ?    Sl   13:28   7:54 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511123 16.3  0.1 87731220 3483456 ?    Sl   13:28   7:53 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511157 16.2  0.1 87706100 3463108 ?    Sl   13:28   7:50 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511435 17.1  0.1 87731220 3478664 ?    Sl   13:28   8:18 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511436 15.7  0.1 87723028 3530900 ?    Sl   13:28   7:38 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511561 15.4  0.1 87714828 3465860 ?    Sl   13:28   7:28 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511632 16.5  0.1 87714852 3465816 ?    Sl   13:28   8:01 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511651 15.6  0.1 87723052 3479312 ?    Sl   13:28   7:35 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511771 16.3  0.1 87731232 3482268 ?    Sl   13:28   7:56 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511885 16.3  0.1 87714848 3460604 ?    Sl   13:28   7:56 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511955 16.3  0.1 87723040 3533716 ?    Sl   13:28   7:53 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511975 15.6  0.1 87714840 3465428 ?    Sl   13:28   7:35 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3511982 16.7  0.1 87731232 3479536 ?    Sl   13:28   8:06 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3512144 16.8  0.1 87714864 3461312 ?    Sl   13:28   8:10 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3512264 15.5  0.1 87731244 3478664 ?    Sl   13:28   7:30 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3512409 16.6  0.1 87714860 3483660 ?    Sl   13:28   8:03 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3512411 15.5  0.1 87723052 3540956 ?    Sl   13:28   7:32 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3512505 15.6  0.1 87714852 3459792 ?    Sl   13:28   7:35 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3512690 16.4  0.1 87731244 3505044 ?    Sl   13:28   7:57 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
# zhaowan+ 3512877 15.8  0.1 87714864 3468032 ?    Sl   13:28   7:40 /home/zhaowangbo/.conda/envs/llava2/bin/python -u -m tools.caption.caption_llava /home/zhaowangbo/data/v2text/raw/meta/split-12/meta_remove_corrupted.csv --dp-size 8 --tp-size 1 --model-path liuhaotian/llava-v1.6-mistral-7b --prompt video
#
# ==== STDERR ====
#  bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
#
# HOST: h800-81
# COMMAND: bash -ic 'ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"'
# ==== STDOUT ====
#  zhaowan+ 2855662  5.0  0.0   8492  5088 ?        Ss   14:17   0:00 bash -ic ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"
# zhaowan+ 2855774  0.0  0.0   7240   588 ?        S    14:17   0:00 sleep 1
# zhaowan+ 2855782  0.0  0.0   7240   592 ?        S    14:17   0:00 sleep 1
# zhaowan+ 2855803  0.0  0.0   6412   724 ?        S    14:17   0:00 grep --color=auto --color=never -E python|sleep|torchrun|colossal
# zhaowan+ 3318198  0.1  0.0 1269428 469156 ?      Sl   04:05   1:00 /home/zhaowangbo/.vscode-server/bin/1e790d77f81672c49be070e04474901747115651/node /home/zhaowangbo/.vscode-server/extensions/ms-python.vscode-pylance-2024.4.1/dist/server.bundle.js --cancellationReceive=file:790961802e0d4cd19d3a255485219c6524349a62b5 --node-ipc --clientProcessId=2537441
#
# ==== STDERR ====
#  bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
#
# HOST: h800-82
# COMMAND: bash -ic 'ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"'
# ==== STDOUT ====
#  zhaowan+  174693  0.0  0.0   8496  5008 ?        S    01:59   0:00 bash -ic sleep 3h; echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-3/meta_remove_corrupted_loadjson_noempty_clean_info.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-3/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-3/meta_remove_corrupted_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-3/meta_remove_corrupted_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# zhaowan+  203444  0.0  0.0   8496  5024 ?        S    02:00   0:00 bash -ic sleep 6h; echo "Getting info of /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info.csv to /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info_info.csv" && cd /home/zhaowangbo/zangwei/opensora/ && python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1 && echo "All Done!"
# zhaowan+  923907  0.8  0.0 21146488 832312 ?     Sl   08:00   3:08 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+  994978  2.2  0.0 28069076 833356 ?     Sl   08:01   8:17 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+  995480 24.4  0.1 52071324 4194416 ?    Il   08:01  92:02 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+  995546 24.5  0.2 58624648 4588168 ?    Il   08:01  92:11 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+  995635 29.8  0.1 55368264 3996440 ?    Il   08:01 112:04 python -m tools.datasets.datautil /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info.csv --output /mnt/hdd/data/panda70m_by/raw/meta/split-5/meta_loadjson_noempty_clean_info_info.csv --format csv --video-info --fmin 1
# zhaowan+
mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586326  0.0  0.0 17142328 221404 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586328  0.0  0.0 17142328 221412 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586330  0.0  0.0 17142328 221412 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586331  0.0  0.0 17142328 221468 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586333  0.0  0.0 17142328 221456 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586335  0.0  0.0 17142328 221560 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586337  0.0  0.0 17142328 221428 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586339  0.0  0.0 17142328 221496 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586341  0.0  0.0 17142328 221528 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586343  0.0  0.0 17142328 221552 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586345  0.0  0.0 17142328 221484 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586347  0.0  0.0 17142328 221452 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586349  0.0  0.0 17142328 221448 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586351  0.0  0.0 17142328 221436 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586353  0.0  0.0 17142328 221508 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586355  0.0  0.0 17142328 221512 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586357  0.0  0.0 17142328 221528 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586359  0.0  0.0 17142328 221428 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586361  0.0  0.0 17142328 221516 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586363  0.0  0.0 17142328 221524 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586365  0.0  0.0 17142328 221456 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586367  0.1  0.0 17142328 221552 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586369  0.0  0.0 17142328 221528 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586371  0.0  0.0 17142328 221528 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586373  0.0  0.0 17142328 221536 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586375  0.0  0.0 17142328 221464 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586377  0.0  0.0 17142328 221444 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586379  0.0  0.0 17142328 221528 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586381  0.0  0.0 17142328 221532 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586383  0.0  0.0 17142328 221536 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586385  0.0  0.0 17142328 221488 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586387  0.0  0.0 17142328 221500 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586389  0.0  0.0 17142328 221524 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586391  0.0  0.0 17142328 221464 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586393  0.0  0.0 17142328 221464 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586395  0.0  0.0 17142328 221536 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586397  0.0  0.0 17142328 221544 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586399  0.0  0.0 17142328 221472 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586401  0.0  0.0 17142328 221448 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586403  0.0  0.0 17142328 221448 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586405  0.0  0.0 17142328 221580 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586407  0.0  0.0 17142328 221480 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586409  0.0  0.0 17142328 221540 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586411  0.0  0.0 17142328 221552 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586413  0.0  0.0 17142328 221556 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586415  0.0  0.0 17142328 221496 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586417  0.0  0.0 17142328 221552 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586419  0.0  0.0 17142328 221560 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586421  0.0  0.0 17142328 221540 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586423  0.0  0.0 17142328 221552 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586425  0.0  0.0 17142328 221540 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586427  0.0  0.0 17142328 221552 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586429  0.0  0.0 17142328 221548 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586431  0.0  0.0 17142328 221556 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586433  0.0  0.0 17142328 221560 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586435  0.0  0.0 17142328 221508 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586437  0.0  0.0 17142328 221560 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586439  0.0  0.0 17142328 221560 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586441  0.0  0.0 17142328 221556 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586443  0.0  0.0 17142328 221512 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586445  0.0  0.0 17142328 221508 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586447  0.0  0.0 17142328 221580 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586449  0.0  0.0 17142328 221508 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586451  0.0  0.0 17142328 221524 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586453  0.0  0.0 17142328 221532 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586455  0.0  0.0 17142328 221516 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586457  0.0  0.0 17142328 221588 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586459  0.0  0.0 17142328 221456 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1586461  0.0  0.0 17142328 221584 pts/7 I+   14:06   0:00 python tools/datasets/filter_panda10m.py --meta_path /mnt/hdd/data/panda70m_by/raw/meta/split-0/meta_remove_corrupted.csv
# zhaowan+ 1589456 10.0  0.0  14176  5352 ?        Ss   14:17   0:00 bash -ic ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"
# zhaowan+ 1589552  0.0  0.0  12124   724 ?        S    14:17   0:00 grep --color=auto --color=never -E python|sleep|torchrun|colossal
#
# ==== STDERR ====
#  bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
#
# HOST: h800-171
# COMMAND: bash -ic 'ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"'
# ==== STDOUT ====
#  zhaowan+  250923  5.0  0.0   8496  5124 ?        Ss   14:17   0:00 bash -ic ps ux | cat | grep --color=never -E "python|sleep|torchrun|colossal"
# zhaowan+  251016  0.0  0.0   6444   720 ?        S    14:17   0:00 grep --color=auto --color=never -E python|sleep|torchrun|colossal
#
# ==== STDERR ====
#  bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell

# %%
nvitop(host)

# %%
kill(, host)

# %% [markdown]
# # Training

# %%
def colossal_run(data_path, load_path=None):
    commands = []
    commands.append(f"cd {OPEN_SORA_HOME}")
    command = f"colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --wandb True --data-path {data_path}"
    if load_path:
        command = f"{command} --load-path {load_path}"
    commands.append(command)
    cmd = " && ".join(commands)
    return cmd


def kill_all():
    commands = []
    commands.append(f"cd {OPEN_SORA_HOME}")
    commands.append('cat hostfile  | xargs -I "{}" ssh "{}" pkill -9 python')
    cmd = " && ".join(commands)
    return cmd

# %% [markdown]
# ### Examples

# %%
host = "h800-80"
log_file = os.path.join(OPEN_SORA_HOME, "logs/train_02.log")
data_path = "/home/zhaowangbo/data/csv/video_image_test_2.csv"
ckpt_path = "outputs/764-STDiT2-XL-2/epoch1-global_step6000"
cmd = colossal_run(data_path, ckpt_path)
print(cmd)
# Out:
# cd /home/zhaowangbo/zangwei/opensora/ && colossalai run --nproc_per_node 8 --hostfile hostfile scripts/train.py configs/opensora-v1-1/train/video.py --wandb True --data-path /home/zhaowangbo/data/csv/video_image_test_2.csv --load-path outputs/764-STDiT2-XL-2/epoch1-global_step6000

# %%
run_command(cmd, host, log_file=log_file, nohup=True)

# %%
cmd = kill_all()
run_command(cmd, host)
# Out:
# HOST: h800-80
# COMMAND: bash -ic 'cd /home/zhaowangbo/zangwei/opensora/ && cat hostfile  | xargs -I "{}" ssh "{}" pkill -9 python'
# ==== STDERR ====
#  bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# pkill: killing pid 382879 failed: Operation not permitted
